# %% [markdown]
# ## Extract the 30 best movies from the action, comedy, drama and horror genres on FilmAffinity, as well as movies from 1980 onwards.

# %%
import requests
from bs4 import BeautifulSoup

# Empty list to store the information about the movies
all_movies = []

# Update the genres with the correct codes
genres = {'AC': 'action', 'CO': 'comedy', 'DR': 'drama', 'TE': 'horror'}  # TE for horror

# Iterate over each genre
for genre_code, genre_name in genres.items():
    # Build the URL for each genre
    genre_url = f'https://www.filmaffinity.com/us/topgen.php?genres=%2B{genre_code}&chv=0&orderby=rc&movietype=movie%7C&country=&fromyear=1980&toyear=2023&ratingcount=2&runtimemin=0&runtimemax=4'
    print(f"Fetching data for genre: {genre_name} from URL: {genre_url}")

    try:
        # Make a GET request to the genre URL and get the page
        req = requests.get(genre_url)
        req.raise_for_status()

        # Create a BeautifulSoup object to parse the HTML
        soup = BeautifulSoup(req.text, 'html.parser')

        # Find the parent container for each movie entry
        movie_cards = soup.select('.movie-card')

        if not movie_cards:
            print(f"No movies found for genre: {genre_name}.")
            continue

        # Process each movie
        for movie_container in movie_cards:
            # Extract the title
            title_element = movie_container.select_one('.mc-title')
            title = title_element.text.strip() if title_element else "Unknown Title"

            # Extract the year
            year_element = movie_container.select_one('.mc-year')
            year = year_element.text.strip() if year_element else "Unknown Year"

            # Extract the actors
            cast_div = movie_container.select_one('.mc-cast')
            actors = [actor.text.strip() for actor in cast_div.select('.nb') if actor.a] if cast_div else []

            # Add the movie information to the list of movies
            all_movies.append({
                "title": title,
                "year": year,
                "genre": genre_name,
                "actors": ", ".join(actors)
            })
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for genre {genre_name}: {e}")

# Display the complete list of collected movies
for i, movie in enumerate(all_movies, 1):
    print(f"{i}. {movie}")
# Out:
# Fetching data for genre: action from URL: https://www.filmaffinity.com/us/topgen.php?genres=%2BAC&chv=0&orderby=rc&movietype=movie%7C&country=&fromyear=1980&toyear=2023&ratingcount=2&runtimemin=0&runtimemax=4
# Fetching data for genre: comedy from URL: https://www.filmaffinity.com/us/topgen.php?genres=%2BCO&chv=0&orderby=rc&movietype=movie%7C&country=&fromyear=1980&toyear=2023&ratingcount=2&runtimemin=0&runtimemax=4
# Fetching data for genre: drama from URL: https://www.filmaffinity.com/us/topgen.php?genres=%2BDR&chv=0&orderby=rc&movietype=movie%7C&country=&fromyear=1980&toyear=2023&ratingcount=2&runtimemin=0&runtimemax=4
# Fetching data for genre: horror from URL: https://www.filmaffinity.com/us/topgen.php?genres=%2BTE&chv=0&orderby=rc&movietype=movie%7C&country=&fromyear=1980&toyear=2023&ratingcount=2&runtimemin=0&runtimemax=4
# 1. {'title': 'The Matrix', 'year': '1999', 'genre': 'action', 'actors': 'Keanu Reeves,, Laurence Fishburne,, Carrie-Anne Moss,, Joe Pantoliano,, Hugo Weaving'}
# 2. {'title': 'The Lord of the Rings: The Fellowship of the Ring', 'year': '2001', 'genre': 'action', 'actors': 'Elijah Wood,, Ian McKellen,, Viggo Mortensen,, Sean Astin,, Sean Bean'}
# 3. {'title': 'Gladiator', 'year': '2000', 'genre': 'action', 'actors': 'Russell Crowe,, Joaquin Phoenix,, Connie Nielsen,, Oliver Reed,, Richard Harris'}
# 4. {'title': 'Kill Bill: Volume 1', 'year': '2003', 'genre': 'action', 'actors': 'Uma Thurman,, Lucy Liu,, Daryl Hannah,, Vivica A. Fox,, Sonny Chiba'}
# 5. {'title': 'The Lord of the Rings: The Return of the King', 'year': '2003', 'genre': 'action', 'actors': 'Elijah Wood,, Viggo Mortensen,, Ian McKellen,, Sean Astin,, Andy Serkis'}
# 6. {'title': 'The Lord of the Rings: The Two Towers', 'year': '2002', 'genre': 'action', 'actors': 'Elijah Wood,, Viggo Mortensen,, Ian McKellen,, Sean Astin,, Andy Serkis'}
# 7. {'title': 'Avatar', 'year': '2009', 'genre': 'action', 'actors': 'Sam Worthington,, Zoe Saldana,, Sigourney Weaver,, Stephen Lang,, Michelle Rodriguez'}
# 8. {'title': 'Inception', 'year': '2010', 'genre': 'action', 'actors': 'Leonardo DiCaprio,, Joseph Gordon-Levitt,, Elliot Page,, Ken Watanabe,, Marion Cotillard'}
# 9. {'title': 'Inglourious Basterds', 'year': '2009', 'genre': 'action', 'actors': 'Brad Pitt,, Christoph Waltz,, Mélanie Laurent,, Diane Kruger,, Michael Fassbender'}
# 10. {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl', 'year': '2003', 'genre': 'action', 'actors': 'Johnny Depp,, Orlando Bloom,, Keira Knightley,, Geoffrey Rush,, Jack Davenport'}
# 11. {'title': 'The Dark Knight', 'year': '2008', 'genre': 'action', 'actors': 'Christian Bale,, Heath Ledger,, Aaron Eckhart,, Michael Caine,, Gary Oldman'}
# 12. {'title': '300', 'year': '2006', 'genre': 'action', 'actors': 'Gerard Butler,, Lena Headey,, David Wenham,, Dominic West,, Vincent Regan'}
# 13. {'title': 'The Terminator', 'year': '1984', 'genre': 'action', 'actors': 'Arnold Schwarzenegger,, Linda Hamilton,, Michael Biehn,, Paul Winfield,, Lance Henriksen'}
# 14. {'title': 'Kill Bill: Volume 2', 'year': '2004', 'genre': 'action', 'actors': 'Uma Thurman,, David Carradine,, Lucy Liu,, Vivica A. Fox,, Gordon Liu'}
# 15. {'title': 'Men in Black (MIB)', 'year': '1997', 'genre': 'action', 'actors': "Tommy Lee Jones,, Will Smith,, Linda Fiorentino,, Vincent D'Onofrio,, Rip Torn"}
# 16. {'title': 'Reservoir Dogs', 'year': '1992', 'genre': 'action', 'actors': 'Tim Roth,, Harvey Keitel,, Steve Buscemi,, Michael Madsen,, Chris Penn'}
# 17. {'title': 'The Departed', 'year': '2006', 'genre': 'action', 'actors': 'Leonardo DiCaprio,, Matt Damon,, Jack Nicholson,, Mark Wahlberg,, Vera Farmiga'}
# 18. {'title': 'Blade Runner', 'year': '1982', 'genre': 'action', 'actors': 'Harrison Ford,, Rutger Hauer,, Sean Young,, Daryl Hannah,, Edward James Olmos'}
# 19. {'title': 'Raiders of the Lost Ark', 'year': '1981', 'genre': 'action', 'actors': 'Harrison Ford,, Karen Allen,, Paul Freeman,, Ronald Lacey,, John Rhys-Davies'}
# 20. {'title': 'V for Vendetta', 'year': '2005', 'genre': 'action', 'actors': 'Natalie Portman,, Hugo Weaving,, Stephen Rea,, John Hurt,, Rupert Graves'}
# 21. {'title': 'City of God', 'year': '2002', 'genre': 'action', 'actors': 'Alexandre Rodrigues,, Leandro Firmino,, Phellipe Haagensen,, Douglas Silva,, Seu Jorge'}
# 22. {'title': 'Terminator 2: Judgment Day', 'year': '1991', 'genre': 'action', 'actors': 'Arnold Schwarzenegger,, Linda Hamilton,, Edward Furlong,, Robert Patrick,, Earl Boen'}
# 23. {'title': "Sin City (Frank Miller's Sin City)", 'year': '2005', 'genre': 'action', 'actors': 'Bruce Willis,, Mickey Rourke,, Clive Owen,, Rosario Dawson,, Jessica Alba'}
# 24. {'title': 'Indiana Jones and the Last Crusade', 'year': '1989', 'genre': 'action', 'actors': 'Harrison Ford,, Sean Connery,, Alison Doody,, Denholm Elliott,, John Rhys-Davies'}
# 25. {'title': 'Die Hard', 'year': '1988', 'genre': 'action', 'actors': 'Bruce Willis,, Bonnie Bedelia,, Alan Rickman,, Alexander Godunov,, Paul Gleason'}
# 26. {'title': 'The Matrix Revolutions', 'year': '2003', 'genre': 'action', 'actors': 'Keanu Reeves,, Laurence Fishburne,, Carrie-Anne Moss,, Hugo Weaving,, Jada Pinkett Smith'}
# 27. {'title': 'X-Men', 'year': '2000', 'genre': 'action', 'actors': 'Hugh Jackman,, Patrick Stewart,, Ian McKellen,, Anna Paquin,, Halle Berry'}
# 28. {'title': 'Indiana Jones and the Temple of Doom', 'year': '1984', 'genre': 'action', 'actors': 'Harrison Ford,, Kate Capshaw,, Ke Huy Quan,, Amrish Puri,, Roshan Seth'}
# 29. {'title': 'Batman', 'year': '1989', 'genre': 'action', 'actors': 'Michael Keaton,, Jack Nicholson,, Kim Basinger,, Robert Wuhl,, Pat Hingle'}
# 30. {'title': 'Batman Begins', 'year': '2005', 'genre': 'action', 'actors': 'Christian Bale,, Liam Neeson,, Katie Holmes,, Cillian Murphy,, Michael Caine'}
# 31. {'title': 'Forrest Gump', 'year': '1994', 'genre': 'comedy', 'actors': 'Tom Hanks,, Robin Wright,, Gary Sinise,, Mykelti Williamson,, Sally Field'}
# 32. {'title': 'Life Is Beautiful', 'year': '1997', 'genre': 'comedy', 'actors': 'Roberto Benigni,, Nicoletta Braschi,, Giorgio Cantarini,, Marisa Paredes,, Giustino Durano'}
# 33. {'title': 'American Beauty', 'year': '1999', 'genre': 'comedy', 'actors': 'Kevin Spacey,, Annette Bening,, Thora Birch,, Allison Janney,, Peter Gallagher'}
# 34. {'title': 'The Lion King', 'year': '1994', 'genre': 'comedy', 'actors': 'Matthew Broderick,, Jeremy Irons,, Jonathan Taylor Thomas,, Moira Kelly'}
# 35. {'title': 'Toy Story', 'year': '1995', 'genre': 'comedy', 'actors': 'Tom Hanks,, Tim Allen,, Don Rickles,, Jim Varney'}
# 36. {'title': 'Amelie', 'year': '2001', 'genre': 'comedy', 'actors': 'Audrey Tautou,, Mathieu Kassovitz,, Rufus Magloire,, Lorella Cravotta,, Serge Merlin'}
# 37. {'title': 'Inglourious Basterds', 'year': '2009', 'genre': 'comedy', 'actors': 'Brad Pitt,, Christoph Waltz,, Mélanie Laurent,, Diane Kruger,, Michael Fassbender'}
# 38. {'title': 'Shrek', 'year': '2001', 'genre': 'comedy', 'actors': 'Mike Myers,, Eddie Murphy,, Cameron Diaz,, John Lithgow'}
# 39. {'title': "There's Something About Mary", 'year': '1998', 'genre': 'comedy', 'actors': 'Cameron Diaz,, Ben Stiller,, Matt Dillon,, Chris Elliott,, Lee Evans'}
# 40. {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl', 'year': '2003', 'genre': 'comedy', 'actors': 'Johnny Depp,, Orlando Bloom,, Keira Knightley,, Geoffrey Rush,, Jack Davenport'}
# 41. {'title': 'Monsters, Inc.', 'year': '2001', 'genre': 'comedy', 'actors': 'John Goodman,, Billy Crystal,, Mary Gibbs,, Steve Buscemi'}
# 42. {'title': 'Up', 'year': '2009', 'genre': 'comedy', 'actors': 'Ed Asner,, Christopher Plummer,, Jordan Nagai,, Bob Peterson'}
# 43. {'title': 'Finding Nemo', 'year': '2003', 'genre': 'comedy', 'actors': 'Albert Brooks,, Ellen DeGeneres,, Alexander Gould,, Willem Dafoe'}
# 44. {'title': 'Back to the Future', 'year': '1985', 'genre': 'comedy', 'actors': 'Michael J. Fox,, Christopher Lloyd,, Lea Thompson,, Crispin Glover,, Claudia Wells'}
# 45. {'title': 'Men in Black (MIB)', 'year': '1997', 'genre': 'comedy', 'actors': "Tommy Lee Jones,, Will Smith,, Linda Fiorentino,, Vincent D'Onofrio,, Rip Torn"}
# 46. {'title': 'Snatch', 'year': '2000', 'genre': 'comedy', 'actors': 'Jason Statham,, Stephen Graham,, Brad Pitt,, Alan Ford,, Vinnie Jones'}
# 47. {'title': 'As Good As It Gets', 'year': '1997', 'genre': 'comedy', 'actors': 'Jack Nicholson,, Helen Hunt,, Greg Kinnear,, Cuba Gooding Jr.,, Skeet Ulrich'}
# 48. {'title': 'Shrek 2', 'year': '2004', 'genre': 'comedy', 'actors': 'Mike Myers,, Eddie Murphy,, Cameron Diaz,, Antonio Banderas'}
# 49. {'title': 'Pretty Woman', 'year': '1990', 'genre': 'comedy', 'actors': 'Julia Roberts,, Richard Gere,, Hector Elizondo,, Jason Alexander,, Ralph Bellamy'}
# 50. {'title': 'Dumb and Dumber', 'year': '1994', 'genre': 'comedy', 'actors': 'Jim Carrey,, Jeff Daniels,, Lauren Holly,, Mike Starr,, Charles Rocket'}
# 51. {'title': 'The Truman Show', 'year': '1998', 'genre': 'comedy', 'actors': 'Jim Carrey,, Laura Linney,, Noah Emmerich,, Ed Harris,, Natascha McElhone'}
# 52. {'title': 'The Big Lebowski', 'year': '1998', 'genre': 'comedy', 'actors': 'Jeff Bridges,, John Goodman,, Julianne Moore,, Steve Buscemi,, David Huddleston'}
# 53. {'title': 'Home Alone', 'year': '1990', 'genre': 'comedy', 'actors': 'Macaulay Culkin,, Joe Pesci,, Daniel Stern,, John Heard,, Roberts Blossom'}
# 54. {'title': 'Ice Age', 'year': '2002', 'genre': 'comedy', 'actors': 'Ray Romano,, John Leguizamo,, Denis Leary,, Jack Black,, Alan Tudyk'}
# 55. {'title': 'Ghostbusters', 'year': '1984', 'genre': 'comedy', 'actors': 'Bill Murray,, Dan Aykroyd,, Sigourney Weaver,, Harold Ramis,, Ernie Hudson'}
# 56. {'title': 'Toy Story 3', 'year': '2010', 'genre': 'comedy', 'actors': 'Tom Hanks,, Tim Allen,, Joan Cusack,, Don Rickles'}
# 57. {'title': 'Toy Story 2', 'year': '1999', 'genre': 'comedy', 'actors': 'Tom Hanks,, Tim Allen,, Joan Cusack,, Don Rickles'}
# 58. {'title': 'American Pie', 'year': '1999', 'genre': 'comedy', 'actors': 'Jason Biggs,, Chris Klein,, Thomas Ian Nicholas,, Alyson Hannigan,, Shannon Elizabeth'}
# 59. {'title': 'The Intouchables', 'year': '2011', 'genre': 'comedy', 'actors': 'François Cluzet,, Omar Sy,, Anne Le Ny,, Audrey Fleurot,, Clotilde Mollet'}
# 60. {'title': 'Scary Movie', 'year': '2000', 'genre': 'comedy', 'actors': 'Anna Faris,, Jon Abrahams,, Carmen Electra,, Shannon Elizabeth,, Kurt Fuller'}
# 61. {'title': 'Forrest Gump', 'year': '1994', 'genre': 'drama', 'actors': 'Tom Hanks,, Robin Wright,, Gary Sinise,, Mykelti Williamson,, Sally Field'}
# 62. {'title': 'Life Is Beautiful', 'year': '1997', 'genre': 'drama', 'actors': 'Roberto Benigni,, Nicoletta Braschi,, Giorgio Cantarini,, Marisa Paredes,, Giustino Durano'}
# 63. {'title': 'Fight Club', 'year': '1999', 'genre': 'drama', 'actors': 'Edward Norton,, Brad Pitt,, Helena Bonham Carter,, Meat Loaf,, Jared Leto'}
# 64. {'title': 'Gladiator', 'year': '2000', 'genre': 'drama', 'actors': 'Russell Crowe,, Joaquin Phoenix,, Connie Nielsen,, Oliver Reed,, Richard Harris'}
# 65. {'title': 'Titanic', 'year': '1997', 'genre': 'drama', 'actors': 'Leonardo DiCaprio,, Kate Winslet,, Billy Zane,, Kathy Bates,, Frances Fisher'}
# 66. {'title': "Schindler's List", 'year': '1993', 'genre': 'drama', 'actors': 'Liam Neeson,, Ben Kingsley,, Ralph Fiennes,, Caroline Goodall,, Jonathan Sagall'}
# 67. {'title': 'American Beauty', 'year': '1999', 'genre': 'drama', 'actors': 'Kevin Spacey,, Annette Bening,, Thora Birch,, Allison Janney,, Peter Gallagher'}
# 68. {'title': 'The Shawshank Redemption', 'year': '1994', 'genre': 'drama', 'actors': 'Tim Robbins,, Morgan Freeman,, Bob Gunton,, James Whitmore,, Gil Bellows'}
# 69. {'title': 'Million Dollar Baby', 'year': '2004', 'genre': 'drama', 'actors': 'Clint Eastwood,, Hilary Swank,, Morgan Freeman,, Anthony Mackie,, Jay Baruchel'}
# 70. {'title': 'The Sixth Sense', 'year': '1999', 'genre': 'drama', 'actors': 'Haley Joel Osment,, Bruce Willis,, Toni Collette,, Olivia Williams,, Trevor Morgan'}
# 71. {'title': 'The Lion King', 'year': '1994', 'genre': 'drama', 'actors': 'Matthew Broderick,, Jeremy Irons,, Jonathan Taylor Thomas,, Moira Kelly'}
# 72. {'title': 'Amelie', 'year': '2001', 'genre': 'drama', 'actors': 'Audrey Tautou,, Mathieu Kassovitz,, Rufus Magloire,, Lorella Cravotta,, Serge Merlin'}
# 73. {'title': 'E.T. the Extra-Terrestrial', 'year': '1982', 'genre': 'drama', 'actors': 'Henry Thomas,, Dee Wallace,, Robert MacNaughton,, Drew Barrymore,, Peter Coyote'}
# 74. {'title': 'The Dark Knight', 'year': '2008', 'genre': 'drama', 'actors': 'Christian Bale,, Heath Ledger,, Aaron Eckhart,, Michael Caine,, Gary Oldman'}
# 75. {'title': 'Braveheart', 'year': '1995', 'genre': 'drama', 'actors': 'Mel Gibson,, Sophie Marceau,, Patrick McGoohan,, Angus MacFadyen,, Catherine McCormack'}
# 76. {'title': 'American History X', 'year': '1998', 'genre': 'drama', 'actors': 'Edward Norton,, Edward Furlong,, Fairuza Balk,, Stacy Keach,, Elliott Gould'}
# 77. {'title': 'The Pianist', 'year': '2002', 'genre': 'drama', 'actors': 'Adrien Brody,, Thomas Kretschmann,, Maureen Lipman,, Ed Stoppard,, Emilia Fox'}
# 78. {'title': 'Gran Torino', 'year': '2008', 'genre': 'drama', 'actors': 'Clint Eastwood,, Christopher Carley,, Bee Vang,, Ahney Her,, John Carroll Lynch'}
# 79. {'title': 'Mystic River', 'year': '2003', 'genre': 'drama', 'actors': 'Sean Penn,, Tim Robbins,, Kevin Bacon,, Laurence Fishburne,, Marcia Gay Harden'}
# 80. {'title': 'The Departed', 'year': '2006', 'genre': 'drama', 'actors': 'Leonardo DiCaprio,, Matt Damon,, Jack Nicholson,, Mark Wahlberg,, Vera Farmiga'}
# 81. {'title': 'Trainspotting', 'year': '1996', 'genre': 'drama', 'actors': 'Ewan McGregor,, Robert Carlyle,, Jonny Lee Miller,, Ewen Bremner,, Kelly MacDonald'}
# 82. {'title': 'Slumdog Millionaire', 'year': '2008', 'genre': 'drama', 'actors': 'Dev Patel,, Freida Pinto,, Madhur Mittal,, Anil Kapoor,, Irrfan Khan'}
# 83. {'title': 'As Good As It Gets', 'year': '1997', 'genre': 'drama', 'actors': 'Jack Nicholson,, Helen Hunt,, Greg Kinnear,, Cuba Gooding Jr.,, Skeet Ulrich'}
# 84. {'title': 'Big Fish', 'year': '2003', 'genre': 'drama', 'actors': 'Ewan McGregor,, Albert Finney,, Billy Crudup,, Jessica Lange,, Alison Lohman'}
# 85. {'title': 'City of God', 'year': '2002', 'genre': 'drama', 'actors': 'Alexandre Rodrigues,, Leandro Firmino,, Phellipe Haagensen,, Douglas Silva,, Seu Jorge'}
# 86. {'title': 'Moulin Rouge', 'year': '2001', 'genre': 'drama', 'actors': 'Nicole Kidman,, Ewan McGregor,, John Leguizamo,, David Wenham,, Jim Broadbent'}
# 87. {'title': 'The Truman Show', 'year': '1998', 'genre': 'drama', 'actors': 'Jim Carrey,, Laura Linney,, Noah Emmerich,, Ed Harris,, Natascha McElhone'}
# 88. {'title': 'The Curious Case of Benjamin Button', 'year': '2008', 'genre': 'drama', 'actors': 'Brad Pitt,, Cate Blanchett,, Taraji P. Henson,, Tilda Swinton,, Jason Flemyng'}
# 89. {'title': 'Full Metal Jacket', 'year': '1987', 'genre': 'drama', 'actors': "Matthew Modine,, Vincent D'Onofrio,, R. Lee Ermey,, Adam Baldwin,, Arliss Howard"}
# 90. {'title': 'Requiem for a Dream', 'year': '2000', 'genre': 'drama', 'actors': 'Jared Leto,, Jennifer Connelly,, Ellen Burstyn,, Marlon Wayans,, Christopher McDonald'}
# 91. {'title': 'The Silence of the Lambs', 'year': '1991', 'genre': 'horror', 'actors': 'Jodie Foster,, Anthony Hopkins,, Scott Glenn,, Ted Levine,, Anthony Heald'}
# 92. {'title': 'The Sixth Sense', 'year': '1999', 'genre': 'horror', 'actors': 'Haley Joel Osment,, Bruce Willis,, Toni Collette,, Olivia Williams,, Trevor Morgan'}
# 93. {'title': 'The Others', 'year': '2001', 'genre': 'horror', 'actors': 'Nicole Kidman,, Fionnula Flanagan,, Christopher Eccleston,, Alakina Mann,, James Bentley'}
# 94. {'title': 'The Shining', 'year': '1980', 'genre': 'horror', 'actors': 'Jack Nicholson,, Shelley Duvall,, Danny Lloyd,, Scatman Crothers,, Barry Nelson'}
# 95. {'title': 'Scary Movie', 'year': '2000', 'genre': 'horror', 'actors': 'Anna Faris,, Jon Abrahams,, Carmen Electra,, Shannon Elizabeth,, Kurt Fuller'}
# 96. {'title': 'Saw', 'year': '2004', 'genre': 'horror', 'actors': 'Cary Elwes,, Leigh Whannell,, Danny Glover,, Monica Potter,, Dina Meyer'}
# 97. {'title': 'I Am Legend', 'year': '2007', 'genre': 'horror', 'actors': 'Will Smith,, Alice Braga,, Salli Richardson-Whitfield,, Paradox Pollack,, Charlie Tahan'}
# 98. {'title': 'Gremlins', 'year': '1984', 'genre': 'horror', 'actors': 'Zach Galligan,, Phoebe Cates,, Hoyt Axton,, Frances Lee McCain,, Dick Miller'}
# 99. {'title': 'The Nightmare Before Christmas', 'year': '1993', 'genre': 'horror', 'actors': "Chris Sarandon,, Catherine O'Hara,, William Hickey,, Glenn Shadix"}
# 100. {'title': 'Corpse Bride', 'year': '2005', 'genre': 'horror', 'actors': 'Johnny Depp,, Helena Bonham Carter,, Emily Watson,, Albert Finney'}
# 101. {'title': 'The Blair Witch Project', 'year': '1999', 'genre': 'horror', 'actors': 'Heather Donahue,, Michael C. Williams,, Joshua Leonard,, Patricia DeCou'}
# 102. {'title': 'The Orphanage', 'year': '2007', 'genre': 'horror', 'actors': 'Belén Rueda,, Fernando Cayo,, Roger Príncep,, Geraldine Chaplin,, Mabel Rivera'}
# 103. {'title': 'Blade', 'year': '1998', 'genre': 'horror', 'actors': 'Wesley Snipes,, Stephen Dorff,, Kris Kristofferson,, Sanaa Lathan,, Donal Logue'}
# 104. {'title': "Bram Stoker's Dracula", 'year': '1992', 'genre': 'horror', 'actors': 'Gary Oldman,, Winona Ryder,, Anthony Hopkins,, Keanu Reeves,, Richard E. Grant'}
# 105. {'title': '[•REC]', 'year': '2007', 'genre': 'horror', 'actors': 'Manuela Velasco,, Ferrán Terraza,, Jorge Serrano,, Pablo Rosso,, David Vert'}
# 106. {'title': 'Sleepy Hollow', 'year': '1999', 'genre': 'horror', 'actors': 'Johnny Depp,, Christina Ricci,, Miranda Richardson,, Michael Gambon,, Casper Van Dien'}
# 107. {'title': 'War of the Worlds', 'year': '2005', 'genre': 'horror', 'actors': 'Tom Cruise,, Dakota Fanning,, Justin Chatwin,, Tim Robbins,, Miranda Otto'}
# 108. {'title': '28 Days Later', 'year': '2002', 'genre': 'horror', 'actors': 'Cillian Murphy,, Naomie Harris,, Megan Burns,, Brendan Gleeson,, Christopher Eccleston'}
# 109. {'title': 'The Ring', 'year': '2002', 'genre': 'horror', 'actors': 'Naomi Watts,, Martin Henderson,, Brian Cox,, David Dorfman,, Daveigh Chase'}
# 110. {'title': 'Cube', 'year': '1997', 'genre': 'horror', 'actors': 'Maurice Dean Wint,, Nicole de Boer,, Nicky Guadagni,, David Hewlett,, Andrew Miller'}
# 111. {'title': 'The Day of the Beast', 'year': '1995', 'genre': 'horror', 'actors': 'Álex Angulo,, Santiago Segura,, Armando de Razza,, María Grazia Cucinotta,, Terele Pávez'}
# 112. {'title': 'World War Z', 'year': '2013', 'genre': 'horror', 'actors': 'Brad Pitt,, Mireille Enos,, Daniella Kertesz,, David Morse,, Matthew Fox'}
# 113. {'title': 'I Know What You Did Last Summer', 'year': '1997', 'genre': 'horror', 'actors': 'Jennifer Love Hewitt,, Sarah Michelle Gellar,, Ryan Phillippe,, Freddie Prinze Jr.,, Johnny Galecki'}
# 114. {'title': 'Interview With the Vampire', 'year': '1994', 'genre': 'horror', 'actors': 'Tom Cruise,, Brad Pitt,, Kirsten Dunst,, Antonio Banderas,, Christian Slater'}
# 115. {'title': 'Scream', 'year': '1996', 'genre': 'horror', 'actors': 'Neve Campbell,, David Arquette,, Courteney Cox,, Matthew Lillard,, Rose McGowan'}
# 116. {'title': 'Zombieland', 'year': '2009', 'genre': 'horror', 'actors': 'Jesse Eisenberg,, Woody Harrelson,, Emma Stone,, Abigail Breslin,, Amber Heard'}
# 117. {'title': 'American Psycho', 'year': '2000', 'genre': 'horror', 'actors': 'Christian Bale,, Willem Dafoe,, Jared Leto,, Josh Lucas,, Samantha Mathis'}
# 118. {'title': 'From Dusk Till Dawn', 'year': '1996', 'genre': 'horror', 'actors': 'George Clooney,, Harvey Keitel,, Juliette Lewis,, Quentin Tarantino,, Salma Hayek'}
# 119. {'title': 'Final Destination', 'year': '2000', 'genre': 'horror', 'actors': 'Devon Sawa,, Ali Larter,, Kerr Smith,, Seann William Scott,, Kristen Cloke'}
# 120. {'title': 'Let the Right One In', 'year': '2008', 'genre': 'horror', 'actors': 'Kåre Hedebrant,, Lina Leandersson,, Per Ragnar,, Henrik Dahl,, Karin Bergquist'}

# %% [markdown]
# ## Save the list of all movies as a csv file.

# %%
import csv

# Specify the filename
filename = "movies.csv"

# Define the header based on the dictionary keys in all_movies
header = ["title", "year", "genre", "actors"]

# Write the data to a CSV file
with open(filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()  # Write the header
    writer.writerows(all_movies)  # Write each movie as a row

print(f"Data successfully written to {filename}")
# Out:
# Data successfully written to movies.csv
