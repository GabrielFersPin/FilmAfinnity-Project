# %% [markdown]
# # Merge the movies and and the oscars lists.

# %%
import pandas as pd

# %%
movies = pd.read_csv('../results/movies_df.csv')
oscars = pd.read_csv('../results/oscars_df.csv')

# %%
movies_oscars = movies.merge(oscars, on="name", how='inner')
movies_oscars
# Out:
#      Unnamed: 0_x                       title  year   genre  \
# 0              18                   Gladiator  2000  action
# 1              20                   Gladiator  2000  action
# 2              63                   Inception  2010  action
# 3              71                   Inception  2010  action
# 4              72        Inglourious Basterds  2009  action
# ..            ...                         ...   ...     ...
# 98            993  Interview With the Vampire  1994  horror
# 99           1013                  Zombieland  2009  horror
# 100          1018             American Psycho  2000  horror
# 101          1022             American Psycho  2000  horror
# 102          1027         From Dusk Till Dawn  1996  horror
#
#                   name  Unnamed: 0_y  nominations
# 0        Russell Crowe           186            1
# 1      Joaquin Phoenix            42            1
# 2    Leonardo DiCaprio            12            1
# 3     Marion Cotillard            10            1
# 4            Brad Pitt           148            1
# ..                 ...           ...          ...
# 98           Brad Pitt           148            1
# 99          Emma Stone           281            2
# 100     Christian Bale           130            1
# 101         Jared Leto           239            1
# 102     George Clooney           264            1
#
# [103 rows x 7 columns]

# %%
movies_oscars.to_csv('movies_oscars.csv')
